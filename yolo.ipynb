# %%
# !nvidia-smi
# Out:
# Thu Nov 28 13:19:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    Off | 00000000:01:00.0  On |                  N/A |
# | N/A   49C    P8              19W / 100W |   1161MiB /  6144MiB |     32%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.2.103 -q

# %%
from IPython import display
display.clear_output()

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5916MiB)
# Setup complete ✅ (20 CPUs, 15.2 GB RAM, 150.0/456.9 GB disk)

# %%
# Your Kaggle username: vishnukanteminence
# Your Kaggle Key: 11506660fbf3f3ec0c94048d4d0aece2
